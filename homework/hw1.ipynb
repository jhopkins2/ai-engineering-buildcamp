# %% [markdown]
# # Homework #1

# %%
from markitdown import MarkItDown
import csv
import os

# %%
csv_fp = "/home/jacob/workspace/maven/ai-engineering-buildcamp/data/books.csv"

# %%
with open(csv_fp, "r") as csvfile:
    books = csv.reader(csvfile)
